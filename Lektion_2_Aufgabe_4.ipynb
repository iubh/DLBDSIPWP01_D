# %% [markdown]
# # Numerische Datentypen und Operatoren, Strings, Collections

# %% [markdown]
# ## Aufgabe A
# Gib den ganzzahligen Teil und den Rest der Division 1587÷27 mit einer Erklärung aus.

# %% [markdown]
# ## Aufgabe B
# Überlege, wie du mit nur einer Codezeile die eindeutigen Werte aus der gegebenen Liste bestimmen und diese ausgeben kannst. Die Reihenfolge muss dabei nicht erhalten bleiben.
#
# Tipp: Mache dir eine bestimmte Collection-Art zunutze.

# %%
my_list = [11, 21, 21, 5, 72, 81, 72, 5, 11, 21, 72, 5]

# %% [markdown]
# ## Aufgabe C
# Extrahiere den Vor- und den Nachnamen aus der Zeichenkette `Einstein, Albert` und gib beide aus. Stelle sicher, dass deine Implementierung auch für andere Namen mit demselben Muster (`Nachname, Vorname`) funktioniert.

# %%
name = "Einstein, Albert"

# %% [markdown]
# ## Aufgabe D
# 1. Erstelle eine Sammlung (Collection), die die folgenden Informationen enthält:
#
# | Land | Bevölkerung | Hauptstadt | Telefonvorwahl |
# |:--------|:---------|:--------|:--------|
# | China | 1,413 Milliarden | Peking | +86 |
# | Deutschland | 84,36 Millionen | Berlin | +49 |
# | Indien | 1,408 Milliarden| Neu-Delhi | +91 |
# | Vereinigtes Königreich | 67,33 Millionen | London | +44 |
#
# **Tipp: Du musst eine verschachtelte Sammlung erstellen.**
#
# 2. Gib die Sammlung aus.
# 3. Gib die Bevölkerungszahl von Indien durch Zugriff auf die Sammlung aus.
